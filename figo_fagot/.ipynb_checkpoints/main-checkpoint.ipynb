# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import re
from collections import Counter

# %%
df = pd.read_csv("df.csv")

# %%
stopwords = pd.read_csv("stopwords_pl.txt")
stopwords = list(stopwords.a)

# %%
new_words = ["nie", "w", "się", "a", "ref"]

# %%
stopwords
# Out:
# ['aby',
#  'ach',
#  'acz',
#  'aczkolwiek',
#  'aj',
#  'albo',
#  'ale',
#  'ależ',
#  'ani',
#  'aż',
#  'bardziej',
#  'bardzo',
#  'bez',
#  'bo',
#  'bowiem',
#  'by',
#  'byli',
#  'bym',
#  'bynajmniej',
#  'być',
#  'był',
#  'była',
#  'było',
#  'były',
#  'będzie',
#  'będą',
#  'cali',
#  'cała',
#  'cały',
#  'chce',
#  'choć',
#  'ci',
#  'ciebie',
#  'cię',
#  'co',
#  'cokolwiek',
#  'coraz',
#  'coś',
#  'czasami',
#  'czasem',
#  'czemu',
#  'czy',
#  'czyli',
#  'często',
#  'daleko',
#  'dla',
#  'dlaczego',
#  'dlatego',
#  'do',
#  'dobrze',
#  'dokąd',
#  'dość',
#  'dr',
#  'dużo',
#  'dwa',
#  'dwaj',
#  'dwie',
#  'dwoje',
#  'dzisiaj',
#  'dziś',
#  'gdy',
#  'gdyby',
#  'gdyż',
#  'gdzie',
#  'gdziekolwiek',
#  'gdzieś',
#  'go',
#  'godz',
#  'hab',
#  'i',
#  'ich',
#  'ii',
#  'iii',
#  'ile',
#  'im',
#  'inna',
#  'inne',
#  'inny',
#  'innych',
#  'inż',
#  'iv',
#  'ix',
#  'iż',
#  'ja',
#  'jak',
#  'jakaś',
#  'jakby',
#  'jaki',
#  'jakichś',
#  'jakie',
#  'jakiś',
#  'jakiż',
#  'jakkolwiek',
#  'jako',
#  'jakoś',
#  'je',
#  'jeden',
#  'jedna',
#  'jednak',
#  'jednakże',
#  'jedno',
#  'jednym',
#  'jedynie',
#  'jego',
#  'jej',
#  'jemu',
#  'jest',
#  'jestem',
#  'jeszcze',
#  'jeśli',
#  'jeżeli',
#  'już',
#  'ją',
#  'każdy',
#  'kiedy',
#  'kierunku',
#  'kilka',
#  'kilku',
#  'kimś',
#  'kto',
#  'ktokolwiek',
#  'ktoś',
#  'która',
#  'które',
#  'którego',
#  'której',
#  'który',
#  'których',
#  'którym',
#  'którzy',
#  'ku',
#  'lat',
#  'lecz',
#  'lub',
#  'ma',
#  'mają',
#  'mam',
#  'mamy',
#  'mało',
#  'mgr',
#  'mi',
#  'miał',
#  'mimo',
#  'między',
#  'mnie',
#  'mną',
#  'mogą',
#  'moi',
#  'moim',
#  'moja',
#  'moje',
#  'może',
#  'możliwe',
#  'można',
#  'mu',
#  'musi',
#  'my',
#  'mój',
#  'na',
#  'nad',
#  'nam',
#  'nami',
#  'nas',
#  'nasi',
#  'nasz',
#  'nasza',
#  'nasze',
#  'naszego',
#  'naszych',
#  'natomiast',
#  'natychmiast',
#  'nawet',
#  'nic',
#  'nich',
#  'nie',
#  'niech',
#  'niego',
#  'niej',
#  'niemu',
#  'nigdy',
#  'nim',
#  'nimi',
#  'nią',
#  'niż',
#  'no',
#  'nowe',
#  'np',
#  'nr',
#  'o',
#  'o.o.',
#  'obok',
#  'od',
#  'ok',
#  'około',
#  'on',
#  'ona',
#  'one',
#  'oni',
#  'ono',
#  'oraz',
#  'oto',
#  'owszem',
#  'pan',
#  'pana',
#  'pani',
#  'pl',
#  'po',
#  'pod',
#  'podczas',
#  'pomimo',
#  'ponad',
#  'ponieważ',
#  'powinien',
#  'powinna',
#  'powinni',
#  'powinno',
#  'poza',
#  'prawie',
#  'prof',
#  'przecież',
#  'przed',
#  'przede',
#  'przedtem',
#  'przez',
#  'przy',
#  'raz',
#  'razie',
#  'roku',
#  'również',
#  'sam',
#  'sama',
#  'się',
#  'skąd',
#  'sobie',
#  'sobą',
#  'sposób',
#  'swoje',
#  'są',
#  'ta',
#  'tak',
#  'taka',
#  'taki',
#  'takich',
#  'takie',
#  'także',
#  'tam',
#  'te',
#  'tego',
#  'tej',
#  'tel',
#  'temu',
#  'ten',
#  'teraz',
#  'też',
#  'to',
#  'tobie',
#  'tobą',
#  'toteż',
#  'trzeba',
#  'tu',
#  'tutaj',
#  'twoi',
#  'twoim',
#  'twoja',
#  'twoje',
#  'twym',
#  'twój',
#  'ty',
#  'tych',
#  'tylko',
#  'tym',
#  'tys',
#  'tzw',
#  'tę',
#  'u',
#  'ul',
#  'vi',
#  'vii',
#  'viii',
#  'vol',
#  'w',
#  'wam',
#  'wami',
#  'was',
#  'wasi',
#  'wasz',
#  'wasza',
#  'wasze',
#  'we',
#  'według',
#  'wie',
#  'wiele',
#  'wielu',
#  'więc',
#  'więcej',
#  'wszyscy',
#  'wszystkich',
#  'wszystkie',
#  'wszystkim',
#  'wszystko',
#  'wtedy',
#  'www',
#  'wy',
#  'właśnie',
#  'wśród',
#  'xi',
#  'xii',
#  'xiii',
#  'xiv',
#  'xv',
#  'z',
#  'za',
#  'zapewne',
#  'zawsze',
#  'zaś',
#  'ze',
#  'zeznowu',
#  'znowu',
#  'znów',
#  'został',
#  'zł',
#  'żaden',
#  'żadna',
#  'żadne',
#  'żadnych',
#  'że',
#  'żeby']

# %%
stopwords = stopwords+new_words

# %%
df = df[df.columns[1:]]

# %%
df.text = df.text.apply(lambda x: x[1:-1])

# %%
df.text.iloc[0]
# Out:
# 'Figo Fagot:, , Raz, dwa, dwa czterdzieści,, cztery puszki torba zmieści., Czterech króli nie doniosę,, jedno jebnę już po drodze., *gul gul gul* ahhh..., Jak w stajence w siatce mam., Kacpi, Melchior i Baltazar,, na mieszkanku dzisiaj faza., (Dzwonek do drzwi!), Tyle człowieku stój., (Czy to są psy?), Zaraz strzeli mnie chuj., (Zagaście szlugi!), Kacpiego piję., (Ściszcie rapsy!), Pierdolę, dzwonię!, , Popek:, Bracia Figo Fagot plus Popek, zryty czosnek, królu Albanii., Dzisiaj razem na kwadracie!, Ram pam pam pam!, , Dzisiaj się najebie razem z braćmi król,, rozjebiemy całe siano, idź pan w chuj!, Nic nie pamiętam, co się działo na kwadracie!, Nic nie pamiętam, polej wódki bracie!, , Najebany nie pamiętam, co robiłem wczoraj,, czterech króli plus pół litra plus wyjebka na mych schodach., Nic nie pamiętam, Jezu jak nakurwia mnie wątroba!, Jakiego mam kaca!, I gdzie jest moja głowa?!, To jest król z Albanii i bracia Figo Fagot!, Dawaj ten towar, usmażę se mózg!, Zaraz się dojebię i polecę jak balon,, dokąd mnie poniesie nie wie nawet Bóg!, Dokąd nas poniesie nie wie nawet tego Bóg!, (Nie wie nawet tego Bóg, nie wie nawet tego duch,, nie wie nawet tego król, nie wie nawet tego Chuchla!, Idź pan w chuj!), , Dzisiaj się najebie razem z braćmi król,, rozjebiemy całe siano, idź pan w chuj!, Nic nie pamiętam, co się działo na kwadracie!, Nic nie pamiętam, polej wódki bracie!, , Figo:, Bania goni banię,, niech ta bania nie ustaje!, Kiedy wóda w żyłach nam tańcuje,, kurwa jak się super czuję!, Trzej królowie na kwadracie,, rozjebiemy wszystko w chacie!, Każde świństwo wypijemy!, Dzisiaj w kimę nie idziemy!, , TRZY!, I wszystkim wódę nalewamy w szklany!, DWA!, Nie marudź, dupy w górę i śpiewamy!, JEDEN!, chapaj wódę, niech ryj pali!, I w górę, i w górę, i w górę!, , Trzy ,dwa, jeden x4, Trzy, dwa, jeden, LUFA! x4, , Dzisiaj się najebie razem z braćmi król,, rozjebiemy całe siano, idź pan w chuj!, Nic nie pamiętam, co się działo na kwadracie!'

# %%
df.text = df.text.apply(lambda x: x.replace("Tekst piosenki:",""))
df.text = df.text.apply(lambda x: x.replace("Ref.",""))
df.text = df.text.apply(lambda x: x.replace("ref",""))
df.text = df.text.apply(lambda x: x.replace("ref.",""))
df.text = df.text.apply(lambda x: x.replace("(Fagot)",""))
df.text = df.text.apply(lambda x: x.replace("(Figo):",""))
df.text = df.text.apply(lambda x: x.replace("(Figo)",""))
df.text = df.text.apply(lambda x: x.replace("1.",""))
df.text = df.text.apply(lambda x: x.replace("I.",""))
df.text = df.text.apply(lambda x: x.replace("Figo Fagot:",""))
df.text = df.text.apply(lambda x: x.replace("Intro:",""))
df.text = df.text.apply(lambda x: x.replace("&nbsp",""))
df.text = df.text.apply(lambda x: x.replace("x2",""))
df.text = df.text.apply(lambda x: x.replace("x4",""))
df.text = df.text.apply(lambda x: x.replace("Poznaj historię zmian tego tekstu",""))

#punctuation
df.text = df.text.apply(lambda x: re.sub(r'[^\w\s]', '', x))
df.text = df.text.apply(lambda x: x.lower())
#stopwords
df.text = df.text.apply(lambda x: x if x not in stopwords else "")

# %%
df.text
# Out:
# 0       raz dwa dwa czterdzieści cztery puszki torba...
# 1       posłuchaj mnie teraz seba odstaw na chwilę p...
# 2     spotkałem ją na lquano disco w dawidach chwilę...
# 3     metal długie włosy ma a kiedy disco gra hiphop...
# 4      bal jak bal disco rżnie na full bal jak bal d...
#                             ...
# 64    piątkowa noc to wódy czas to jest wódy czas 10...
# 65    klub noc nocny czar pod pachami adidas podchod...
# 66    wędkować pozwól wędkować daj no nie bądź taka ...
# 67    dzieńdobry tu bracia figo fagot zapraszamy do ...
# 68    wzrokiem szukam cię  nie widzę ryj maciory prz...
# Name: text, Length: 69, dtype: object

# %%
def remove_empty(lst):
    return [x for x in lst if len(x)>0]

# %%
def remove_stopwords(lst):
    return [x for x in lst if x not in stopwords]

# %%
df['words']= df.text.apply(lambda x: x.split(" "))

# %%
df['words'] = df['words'].apply(lambda x: remove_stopwords(x))

# %%
df['words']
# Out:
# 0     [, , czterdzieści, cztery, puszki, torba, zmie...
# 1     [, , posłuchaj, seba, odstaw, chwilę, piwo, po...
# 2     [spotkałem, lquano, disco, dawidach, chwilę, s...
# 3     [metal, długie, włosy, disco, gra, hiphop, kro...
# 4     [, bal, bal, disco, rżnie, full, bal, bal, dis...
#                             ...
# 64    [piątkowa, noc, wódy, czas, wódy, czas, 100, z...
# 65    [klub, noc, nocny, czar, pachami, adidas, podc...
# 66    [wędkować, pozwól, wędkować, daj, bądź, laj, l...
# 67    [dzieńdobry, bracia, figo, fagot, zapraszamy, ...
# 68    [wzrokiem, szukam, , widzę, ryj, maciory, prze...
# Name: words, Length: 69, dtype: object

# %%
df['words'] = df['words'].apply(lambda x: remove_empty(x))

# %%
df['counter'] = df['words'].apply(lambda x: Counter(x))

# %%
df['top_10']=df['counter'].apply(lambda x: sorted(x.items(), key=lambda kv: kv[1], reverse=True)[:10] )

# %%
lab= [x[0] for x in df['top_10'].iloc[0]]
val = [x[1] for x in df['top_10'].iloc[0]]

# %%
plt.barh(lab, val)
# Out:
# <BarContainer object of 10 artists>

# %%
for i in range(10):
    f, axs = plt.subplots(len(df),2,figsize=(15,15))

    lab= [x[0] for x in df['top_10'].iloc[i]]
    val = [x[1] for x in df['top_10'].iloc[i]]
    plt.barh(lab, val)
    plt.title(df.names.iloc[i])
    plt.xlabel("Liczba wystapenie slowa")
#     plt.savefig("Top10wordsBySongBFF")
    plt.show()

# %%
from nltk import word_tokenize
import nltk

# %%
token = word_tokenize(df.text.iloc[0])

bigrm = nltk.bigrams(token)
list(bigrm)
# Out:
# [('raz', 'dwa'),
#  ('dwa', 'dwa'),
#  ('dwa', 'czterdzieści'),
#  ('czterdzieści', 'cztery'),
#  ('cztery', 'puszki'),
#  ('puszki', 'torba'),
#  ('torba', 'zmieści'),
#  ('zmieści', 'czterech'),
#  ('czterech', 'króli'),
#  ('króli', 'nie'),
#  ('nie', 'doniosę'),
#  ('doniosę', 'jedno'),
#  ('jedno', 'jebnę'),
#  ('jebnę', 'już'),
#  ('już', 'po'),
#  ('po', 'drodze'),
#  ('drodze', 'gul'),
#  ('gul', 'gul'),
#  ('gul', 'gul'),
#  ('gul', 'ahhh'),
#  ('ahhh', 'jak'),
#  ('jak', 'w'),
#  ('w', 'stajence'),
#  ('stajence', 'w'),
#  ('w', 'siatce'),
#  ('siatce', 'mam'),
#  ('mam', 'kacpi'),
#  ('kacpi', 'melchior'),
#  ('melchior', 'i'),
#  ('i', 'baltazar'),
#  ('baltazar', 'na'),
#  ('na', 'mieszkanku'),
#  ('mieszkanku', 'dzisiaj'),
#  ('dzisiaj', 'faza'),
#  ('faza', 'dzwonek'),
#  ('dzwonek', 'do'),
#  ('do', 'drzwi'),
#  ('drzwi', 'tyle'),
#  ('tyle', 'człowieku'),
#  ('człowieku', 'stój'),
#  ('stój', 'czy'),
#  ('czy', 'to'),
#  ('to', 'są'),
#  ('są', 'psy'),
#  ('psy', 'zaraz'),
#  ('zaraz', 'strzeli'),
#  ('strzeli', 'mnie'),
#  ('mnie', 'chuj'),
#  ('chuj', 'zagaście'),
#  ('zagaście', 'szlugi'),
#  ('szlugi', 'kacpiego'),
#  ('kacpiego', 'piję'),
#  ('piję', 'ściszcie'),
#  ('ściszcie', 'rapsy'),
#  ('rapsy', 'pierdolę'),
#  ('pierdolę', 'dzwonię'),
#  ('dzwonię', 'popek'),
#  ('popek', 'bracia'),
#  ('bracia', 'figo'),
#  ('figo', 'fagot'),
#  ('fagot', 'plus'),
#  ('plus', 'popek'),
#  ('popek', 'zryty'),
#  ('zryty', 'czosnek'),
#  ('czosnek', 'królu'),
#  ('królu', 'albanii'),
#  ('albanii', 'dzisiaj'),
#  ('dzisiaj', 'razem'),
#  ('razem', 'na'),
#  ('na', 'kwadracie'),
#  ('kwadracie', 'ram'),
#  ('ram', 'pam'),
#  ('pam', 'pam'),
#  ('pam', 'pam'),
#  ('pam', 'dzisiaj'),
#  ('dzisiaj', 'się'),
#  ('się', 'najebie'),
#  ('najebie', 'razem'),
#  ('razem', 'z'),
#  ('z', 'braćmi'),
#  ('braćmi', 'król'),
#  ('król', 'rozjebiemy'),
#  ('rozjebiemy', 'całe'),
#  ('całe', 'siano'),
#  ('siano', 'idź'),
#  ('idź', 'pan'),
#  ('pan', 'w'),
#  ('w', 'chuj'),
#  ('chuj', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'co'),
#  ('co', 'się'),
#  ('się', 'działo'),
#  ('działo', 'na'),
#  ('na', 'kwadracie'),
#  ('kwadracie', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'polej'),
#  ('polej', 'wódki'),
#  ('wódki', 'bracie'),
#  ('bracie', 'najebany'),
#  ('najebany', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'co'),
#  ('co', 'robiłem'),
#  ('robiłem', 'wczoraj'),
#  ('wczoraj', 'czterech'),
#  ('czterech', 'króli'),
#  ('króli', 'plus'),
#  ('plus', 'pół'),
#  ('pół', 'litra'),
#  ('litra', 'plus'),
#  ('plus', 'wyjebka'),
#  ('wyjebka', 'na'),
#  ('na', 'mych'),
#  ('mych', 'schodach'),
#  ('schodach', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'jezu'),
#  ('jezu', 'jak'),
#  ('jak', 'nakurwia'),
#  ('nakurwia', 'mnie'),
#  ('mnie', 'wątroba'),
#  ('wątroba', 'jakiego'),
#  ('jakiego', 'mam'),
#  ('mam', 'kaca'),
#  ('kaca', 'i'),
#  ('i', 'gdzie'),
#  ('gdzie', 'jest'),
#  ('jest', 'moja'),
#  ('moja', 'głowa'),
#  ('głowa', 'to'),
#  ('to', 'jest'),
#  ('jest', 'król'),
#  ('król', 'z'),
#  ('z', 'albanii'),
#  ('albanii', 'i'),
#  ('i', 'bracia'),
#  ('bracia', 'figo'),
#  ('figo', 'fagot'),
#  ('fagot', 'dawaj'),
#  ('dawaj', 'ten'),
#  ('ten', 'towar'),
#  ('towar', 'usmażę'),
#  ('usmażę', 'se'),
#  ('se', 'mózg'),
#  ('mózg', 'zaraz'),
#  ('zaraz', 'się'),
#  ('się', 'dojebię'),
#  ('dojebię', 'i'),
#  ('i', 'polecę'),
#  ('polecę', 'jak'),
#  ('jak', 'balon'),
#  ('balon', 'dokąd'),
#  ('dokąd', 'mnie'),
#  ('mnie', 'poniesie'),
#  ('poniesie', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'bóg'),
#  ('bóg', 'dokąd'),
#  ('dokąd', 'nas'),
#  ('nas', 'poniesie'),
#  ('poniesie', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'tego'),
#  ('tego', 'bóg'),
#  ('bóg', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'tego'),
#  ('tego', 'bóg'),
#  ('bóg', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'tego'),
#  ('tego', 'duch'),
#  ('duch', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'tego'),
#  ('tego', 'król'),
#  ('król', 'nie'),
#  ('nie', 'wie'),
#  ('wie', 'nawet'),
#  ('nawet', 'tego'),
#  ('tego', 'chuchla'),
#  ('chuchla', 'idź'),
#  ('idź', 'pan'),
#  ('pan', 'w'),
#  ('w', 'chuj'),
#  ('chuj', 'dzisiaj'),
#  ('dzisiaj', 'się'),
#  ('się', 'najebie'),
#  ('najebie', 'razem'),
#  ('razem', 'z'),
#  ('z', 'braćmi'),
#  ('braćmi', 'król'),
#  ('król', 'rozjebiemy'),
#  ('rozjebiemy', 'całe'),
#  ('całe', 'siano'),
#  ('siano', 'idź'),
#  ('idź', 'pan'),
#  ('pan', 'w'),
#  ('w', 'chuj'),
#  ('chuj', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'co'),
#  ('co', 'się'),
#  ('się', 'działo'),
#  ('działo', 'na'),
#  ('na', 'kwadracie'),
#  ('kwadracie', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'polej'),
#  ('polej', 'wódki'),
#  ('wódki', 'bracie'),
#  ('bracie', 'figo'),
#  ('figo', 'bania'),
#  ('bania', 'goni'),
#  ('goni', 'banię'),
#  ('banię', 'niech'),
#  ('niech', 'ta'),
#  ('ta', 'bania'),
#  ('bania', 'nie'),
#  ('nie', 'ustaje'),
#  ('ustaje', 'kiedy'),
#  ('kiedy', 'wóda'),
#  ('wóda', 'w'),
#  ('w', 'żyłach'),
#  ('żyłach', 'nam'),
#  ('nam', 'tańcuje'),
#  ('tańcuje', 'kurwa'),
#  ('kurwa', 'jak'),
#  ('jak', 'się'),
#  ('się', 'super'),
#  ('super', 'czuję'),
#  ('czuję', 'trzej'),
#  ('trzej', 'królowie'),
#  ('królowie', 'na'),
#  ('na', 'kwadracie'),
#  ('kwadracie', 'rozjebiemy'),
#  ('rozjebiemy', 'wszystko'),
#  ('wszystko', 'w'),
#  ('w', 'chacie'),
#  ('chacie', 'każde'),
#  ('każde', 'świństwo'),
#  ('świństwo', 'wypijemy'),
#  ('wypijemy', 'dzisiaj'),
#  ('dzisiaj', 'w'),
#  ('w', 'kimę'),
#  ('kimę', 'nie'),
#  ('nie', 'idziemy'),
#  ('idziemy', 'trzy'),
#  ('trzy', 'i'),
#  ('i', 'wszystkim'),
#  ('wszystkim', 'wódę'),
#  ('wódę', 'nalewamy'),
#  ('nalewamy', 'w'),
#  ('w', 'szklany'),
#  ('szklany', 'dwa'),
#  ('dwa', 'nie'),
#  ('nie', 'marudź'),
#  ('marudź', 'dupy'),
#  ('dupy', 'w'),
#  ('w', 'górę'),
#  ('górę', 'i'),
#  ('i', 'śpiewamy'),
#  ('śpiewamy', 'jeden'),
#  ('jeden', 'chapaj'),
#  ('chapaj', 'wódę'),
#  ('wódę', 'niech'),
#  ('niech', 'ryj'),
#  ('ryj', 'pali'),
#  ('pali', 'i'),
#  ('i', 'w'),
#  ('w', 'górę'),
#  ('górę', 'i'),
#  ('i', 'w'),
#  ('w', 'górę'),
#  ('górę', 'i'),
#  ('i', 'w'),
#  ('w', 'górę'),
#  ('górę', 'trzy'),
#  ('trzy', 'dwa'),
#  ('dwa', 'jeden'),
#  ('jeden', 'trzy'),
#  ('trzy', 'dwa'),
#  ('dwa', 'jeden'),
#  ('jeden', 'lufa'),
#  ('lufa', 'dzisiaj'),
#  ('dzisiaj', 'się'),
#  ('się', 'najebie'),
#  ('najebie', 'razem'),
#  ('razem', 'z'),
#  ('z', 'braćmi'),
#  ('braćmi', 'król'),
#  ('król', 'rozjebiemy'),
#  ('rozjebiemy', 'całe'),
#  ('całe', 'siano'),
#  ('siano', 'idź'),
#  ('idź', 'pan'),
#  ('pan', 'w'),
#  ('w', 'chuj'),
#  ('chuj', 'nic'),
#  ('nic', 'nie'),
#  ('nie', 'pamiętam'),
#  ('pamiętam', 'co'),
#  ('co', 'się'),
#  ('się', 'działo'),
#  ('działo', 'na'),
#  ('na', 'kwadracie')]

# %%
df['bigram']= df.text.apply(lambda x : list(nltk.bigrams(word_tokenize(x))))

# %%
# for x in df['bigram']:
#     print(x)
#     print("********")
#     print("\n")

# %%
from nltk.util import ngrams

# %%
trigrams=ngrams(token,3)
list(trigrams)
# Out:
# [('raz', 'dwa', 'dwa'),
#  ('dwa', 'dwa', 'czterdzieści'),
#  ('dwa', 'czterdzieści', 'cztery'),
#  ('czterdzieści', 'cztery', 'puszki'),
#  ('cztery', 'puszki', 'torba'),
#  ('puszki', 'torba', 'zmieści'),
#  ('torba', 'zmieści', 'czterech'),
#  ('zmieści', 'czterech', 'króli'),
#  ('czterech', 'króli', 'nie'),
#  ('króli', 'nie', 'doniosę'),
#  ('nie', 'doniosę', 'jedno'),
#  ('doniosę', 'jedno', 'jebnę'),
#  ('jedno', 'jebnę', 'już'),
#  ('jebnę', 'już', 'po'),
#  ('już', 'po', 'drodze'),
#  ('po', 'drodze', 'gul'),
#  ('drodze', 'gul', 'gul'),
#  ('gul', 'gul', 'gul'),
#  ('gul', 'gul', 'ahhh'),
#  ('gul', 'ahhh', 'jak'),
#  ('ahhh', 'jak', 'w'),
#  ('jak', 'w', 'stajence'),
#  ('w', 'stajence', 'w'),
#  ('stajence', 'w', 'siatce'),
#  ('w', 'siatce', 'mam'),
#  ('siatce', 'mam', 'kacpi'),
#  ('mam', 'kacpi', 'melchior'),
#  ('kacpi', 'melchior', 'i'),
#  ('melchior', 'i', 'baltazar'),
#  ('i', 'baltazar', 'na'),
#  ('baltazar', 'na', 'mieszkanku'),
#  ('na', 'mieszkanku', 'dzisiaj'),
#  ('mieszkanku', 'dzisiaj', 'faza'),
#  ('dzisiaj', 'faza', 'dzwonek'),
#  ('faza', 'dzwonek', 'do'),
#  ('dzwonek', 'do', 'drzwi'),
#  ('do', 'drzwi', 'tyle'),
#  ('drzwi', 'tyle', 'człowieku'),
#  ('tyle', 'człowieku', 'stój'),
#  ('człowieku', 'stój', 'czy'),
#  ('stój', 'czy', 'to'),
#  ('czy', 'to', 'są'),
#  ('to', 'są', 'psy'),
#  ('są', 'psy', 'zaraz'),
#  ('psy', 'zaraz', 'strzeli'),
#  ('zaraz', 'strzeli', 'mnie'),
#  ('strzeli', 'mnie', 'chuj'),
#  ('mnie', 'chuj', 'zagaście'),
#  ('chuj', 'zagaście', 'szlugi'),
#  ('zagaście', 'szlugi', 'kacpiego'),
#  ('szlugi', 'kacpiego', 'piję'),
#  ('kacpiego', 'piję', 'ściszcie'),
#  ('piję', 'ściszcie', 'rapsy'),
#  ('ściszcie', 'rapsy', 'pierdolę'),
#  ('rapsy', 'pierdolę', 'dzwonię'),
#  ('pierdolę', 'dzwonię', 'popek'),
#  ('dzwonię', 'popek', 'bracia'),
#  ('popek', 'bracia', 'figo'),
#  ('bracia', 'figo', 'fagot'),
#  ('figo', 'fagot', 'plus'),
#  ('fagot', 'plus', 'popek'),
#  ('plus', 'popek', 'zryty'),
#  ('popek', 'zryty', 'czosnek'),
#  ('zryty', 'czosnek', 'królu'),
#  ('czosnek', 'królu', 'albanii'),
#  ('królu', 'albanii', 'dzisiaj'),
#  ('albanii', 'dzisiaj', 'razem'),
#  ('dzisiaj', 'razem', 'na'),
#  ('razem', 'na', 'kwadracie'),
#  ('na', 'kwadracie', 'ram'),
#  ('kwadracie', 'ram', 'pam'),
#  ('ram', 'pam', 'pam'),
#  ('pam', 'pam', 'pam'),
#  ('pam', 'pam', 'dzisiaj'),
#  ('pam', 'dzisiaj', 'się'),
#  ('dzisiaj', 'się', 'najebie'),
#  ('się', 'najebie', 'razem'),
#  ('najebie', 'razem', 'z'),
#  ('razem', 'z', 'braćmi'),
#  ('z', 'braćmi', 'król'),
#  ('braćmi', 'król', 'rozjebiemy'),
#  ('król', 'rozjebiemy', 'całe'),
#  ('rozjebiemy', 'całe', 'siano'),
#  ('całe', 'siano', 'idź'),
#  ('siano', 'idź', 'pan'),
#  ('idź', 'pan', 'w'),
#  ('pan', 'w', 'chuj'),
#  ('w', 'chuj', 'nic'),
#  ('chuj', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'co'),
#  ('pamiętam', 'co', 'się'),
#  ('co', 'się', 'działo'),
#  ('się', 'działo', 'na'),
#  ('działo', 'na', 'kwadracie'),
#  ('na', 'kwadracie', 'nic'),
#  ('kwadracie', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'polej'),
#  ('pamiętam', 'polej', 'wódki'),
#  ('polej', 'wódki', 'bracie'),
#  ('wódki', 'bracie', 'najebany'),
#  ('bracie', 'najebany', 'nie'),
#  ('najebany', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'co'),
#  ('pamiętam', 'co', 'robiłem'),
#  ('co', 'robiłem', 'wczoraj'),
#  ('robiłem', 'wczoraj', 'czterech'),
#  ('wczoraj', 'czterech', 'króli'),
#  ('czterech', 'króli', 'plus'),
#  ('króli', 'plus', 'pół'),
#  ('plus', 'pół', 'litra'),
#  ('pół', 'litra', 'plus'),
#  ('litra', 'plus', 'wyjebka'),
#  ('plus', 'wyjebka', 'na'),
#  ('wyjebka', 'na', 'mych'),
#  ('na', 'mych', 'schodach'),
#  ('mych', 'schodach', 'nic'),
#  ('schodach', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'jezu'),
#  ('pamiętam', 'jezu', 'jak'),
#  ('jezu', 'jak', 'nakurwia'),
#  ('jak', 'nakurwia', 'mnie'),
#  ('nakurwia', 'mnie', 'wątroba'),
#  ('mnie', 'wątroba', 'jakiego'),
#  ('wątroba', 'jakiego', 'mam'),
#  ('jakiego', 'mam', 'kaca'),
#  ('mam', 'kaca', 'i'),
#  ('kaca', 'i', 'gdzie'),
#  ('i', 'gdzie', 'jest'),
#  ('gdzie', 'jest', 'moja'),
#  ('jest', 'moja', 'głowa'),
#  ('moja', 'głowa', 'to'),
#  ('głowa', 'to', 'jest'),
#  ('to', 'jest', 'król'),
#  ('jest', 'król', 'z'),
#  ('król', 'z', 'albanii'),
#  ('z', 'albanii', 'i'),
#  ('albanii', 'i', 'bracia'),
#  ('i', 'bracia', 'figo'),
#  ('bracia', 'figo', 'fagot'),
#  ('figo', 'fagot', 'dawaj'),
#  ('fagot', 'dawaj', 'ten'),
#  ('dawaj', 'ten', 'towar'),
#  ('ten', 'towar', 'usmażę'),
#  ('towar', 'usmażę', 'se'),
#  ('usmażę', 'se', 'mózg'),
#  ('se', 'mózg', 'zaraz'),
#  ('mózg', 'zaraz', 'się'),
#  ('zaraz', 'się', 'dojebię'),
#  ('się', 'dojebię', 'i'),
#  ('dojebię', 'i', 'polecę'),
#  ('i', 'polecę', 'jak'),
#  ('polecę', 'jak', 'balon'),
#  ('jak', 'balon', 'dokąd'),
#  ('balon', 'dokąd', 'mnie'),
#  ('dokąd', 'mnie', 'poniesie'),
#  ('mnie', 'poniesie', 'nie'),
#  ('poniesie', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'bóg'),
#  ('nawet', 'bóg', 'dokąd'),
#  ('bóg', 'dokąd', 'nas'),
#  ('dokąd', 'nas', 'poniesie'),
#  ('nas', 'poniesie', 'nie'),
#  ('poniesie', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'tego'),
#  ('nawet', 'tego', 'bóg'),
#  ('tego', 'bóg', 'nie'),
#  ('bóg', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'tego'),
#  ('nawet', 'tego', 'bóg'),
#  ('tego', 'bóg', 'nie'),
#  ('bóg', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'tego'),
#  ('nawet', 'tego', 'duch'),
#  ('tego', 'duch', 'nie'),
#  ('duch', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'tego'),
#  ('nawet', 'tego', 'król'),
#  ('tego', 'król', 'nie'),
#  ('król', 'nie', 'wie'),
#  ('nie', 'wie', 'nawet'),
#  ('wie', 'nawet', 'tego'),
#  ('nawet', 'tego', 'chuchla'),
#  ('tego', 'chuchla', 'idź'),
#  ('chuchla', 'idź', 'pan'),
#  ('idź', 'pan', 'w'),
#  ('pan', 'w', 'chuj'),
#  ('w', 'chuj', 'dzisiaj'),
#  ('chuj', 'dzisiaj', 'się'),
#  ('dzisiaj', 'się', 'najebie'),
#  ('się', 'najebie', 'razem'),
#  ('najebie', 'razem', 'z'),
#  ('razem', 'z', 'braćmi'),
#  ('z', 'braćmi', 'król'),
#  ('braćmi', 'król', 'rozjebiemy'),
#  ('król', 'rozjebiemy', 'całe'),
#  ('rozjebiemy', 'całe', 'siano'),
#  ('całe', 'siano', 'idź'),
#  ('siano', 'idź', 'pan'),
#  ('idź', 'pan', 'w'),
#  ('pan', 'w', 'chuj'),
#  ('w', 'chuj', 'nic'),
#  ('chuj', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'co'),
#  ('pamiętam', 'co', 'się'),
#  ('co', 'się', 'działo'),
#  ('się', 'działo', 'na'),
#  ('działo', 'na', 'kwadracie'),
#  ('na', 'kwadracie', 'nic'),
#  ('kwadracie', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'polej'),
#  ('pamiętam', 'polej', 'wódki'),
#  ('polej', 'wódki', 'bracie'),
#  ('wódki', 'bracie', 'figo'),
#  ('bracie', 'figo', 'bania'),
#  ('figo', 'bania', 'goni'),
#  ('bania', 'goni', 'banię'),
#  ('goni', 'banię', 'niech'),
#  ('banię', 'niech', 'ta'),
#  ('niech', 'ta', 'bania'),
#  ('ta', 'bania', 'nie'),
#  ('bania', 'nie', 'ustaje'),
#  ('nie', 'ustaje', 'kiedy'),
#  ('ustaje', 'kiedy', 'wóda'),
#  ('kiedy', 'wóda', 'w'),
#  ('wóda', 'w', 'żyłach'),
#  ('w', 'żyłach', 'nam'),
#  ('żyłach', 'nam', 'tańcuje'),
#  ('nam', 'tańcuje', 'kurwa'),
#  ('tańcuje', 'kurwa', 'jak'),
#  ('kurwa', 'jak', 'się'),
#  ('jak', 'się', 'super'),
#  ('się', 'super', 'czuję'),
#  ('super', 'czuję', 'trzej'),
#  ('czuję', 'trzej', 'królowie'),
#  ('trzej', 'królowie', 'na'),
#  ('królowie', 'na', 'kwadracie'),
#  ('na', 'kwadracie', 'rozjebiemy'),
#  ('kwadracie', 'rozjebiemy', 'wszystko'),
#  ('rozjebiemy', 'wszystko', 'w'),
#  ('wszystko', 'w', 'chacie'),
#  ('w', 'chacie', 'każde'),
#  ('chacie', 'każde', 'świństwo'),
#  ('każde', 'świństwo', 'wypijemy'),
#  ('świństwo', 'wypijemy', 'dzisiaj'),
#  ('wypijemy', 'dzisiaj', 'w'),
#  ('dzisiaj', 'w', 'kimę'),
#  ('w', 'kimę', 'nie'),
#  ('kimę', 'nie', 'idziemy'),
#  ('nie', 'idziemy', 'trzy'),
#  ('idziemy', 'trzy', 'i'),
#  ('trzy', 'i', 'wszystkim'),
#  ('i', 'wszystkim', 'wódę'),
#  ('wszystkim', 'wódę', 'nalewamy'),
#  ('wódę', 'nalewamy', 'w'),
#  ('nalewamy', 'w', 'szklany'),
#  ('w', 'szklany', 'dwa'),
#  ('szklany', 'dwa', 'nie'),
#  ('dwa', 'nie', 'marudź'),
#  ('nie', 'marudź', 'dupy'),
#  ('marudź', 'dupy', 'w'),
#  ('dupy', 'w', 'górę'),
#  ('w', 'górę', 'i'),
#  ('górę', 'i', 'śpiewamy'),
#  ('i', 'śpiewamy', 'jeden'),
#  ('śpiewamy', 'jeden', 'chapaj'),
#  ('jeden', 'chapaj', 'wódę'),
#  ('chapaj', 'wódę', 'niech'),
#  ('wódę', 'niech', 'ryj'),
#  ('niech', 'ryj', 'pali'),
#  ('ryj', 'pali', 'i'),
#  ('pali', 'i', 'w'),
#  ('i', 'w', 'górę'),
#  ('w', 'górę', 'i'),
#  ('górę', 'i', 'w'),
#  ('i', 'w', 'górę'),
#  ('w', 'górę', 'i'),
#  ('górę', 'i', 'w'),
#  ('i', 'w', 'górę'),
#  ('w', 'górę', 'trzy'),
#  ('górę', 'trzy', 'dwa'),
#  ('trzy', 'dwa', 'jeden'),
#  ('dwa', 'jeden', 'trzy'),
#  ('jeden', 'trzy', 'dwa'),
#  ('trzy', 'dwa', 'jeden'),
#  ('dwa', 'jeden', 'lufa'),
#  ('jeden', 'lufa', 'dzisiaj'),
#  ('lufa', 'dzisiaj', 'się'),
#  ('dzisiaj', 'się', 'najebie'),
#  ('się', 'najebie', 'razem'),
#  ('najebie', 'razem', 'z'),
#  ('razem', 'z', 'braćmi'),
#  ('z', 'braćmi', 'król'),
#  ('braćmi', 'król', 'rozjebiemy'),
#  ('król', 'rozjebiemy', 'całe'),
#  ('rozjebiemy', 'całe', 'siano'),
#  ('całe', 'siano', 'idź'),
#  ('siano', 'idź', 'pan'),
#  ('idź', 'pan', 'w'),
#  ('pan', 'w', 'chuj'),
#  ('w', 'chuj', 'nic'),
#  ('chuj', 'nic', 'nie'),
#  ('nic', 'nie', 'pamiętam'),
#  ('nie', 'pamiętam', 'co'),
#  ('pamiętam', 'co', 'się'),
#  ('co', 'się', 'działo'),
#  ('się', 'działo', 'na'),
#  ('działo', 'na', 'kwadracie')]

# %%
fourgrams=ngrams(token,4)
list(fourgrams)
# Out:
# [('raz', 'dwa', 'dwa', 'czterdzieści'),
#  ('dwa', 'dwa', 'czterdzieści', 'cztery'),
#  ('dwa', 'czterdzieści', 'cztery', 'puszki'),
#  ('czterdzieści', 'cztery', 'puszki', 'torba'),
#  ('cztery', 'puszki', 'torba', 'zmieści'),
#  ('puszki', 'torba', 'zmieści', 'czterech'),
#  ('torba', 'zmieści', 'czterech', 'króli'),
#  ('zmieści', 'czterech', 'króli', 'nie'),
#  ('czterech', 'króli', 'nie', 'doniosę'),
#  ('króli', 'nie', 'doniosę', 'jedno'),
#  ('nie', 'doniosę', 'jedno', 'jebnę'),
#  ('doniosę', 'jedno', 'jebnę', 'już'),
#  ('jedno', 'jebnę', 'już', 'po'),
#  ('jebnę', 'już', 'po', 'drodze'),
#  ('już', 'po', 'drodze', 'gul'),
#  ('po', 'drodze', 'gul', 'gul'),
#  ('drodze', 'gul', 'gul', 'gul'),
#  ('gul', 'gul', 'gul', 'ahhh'),
#  ('gul', 'gul', 'ahhh', 'jak'),
#  ('gul', 'ahhh', 'jak', 'w'),
#  ('ahhh', 'jak', 'w', 'stajence'),
#  ('jak', 'w', 'stajence', 'w'),
#  ('w', 'stajence', 'w', 'siatce'),
#  ('stajence', 'w', 'siatce', 'mam'),
#  ('w', 'siatce', 'mam', 'kacpi'),
#  ('siatce', 'mam', 'kacpi', 'melchior'),
#  ('mam', 'kacpi', 'melchior', 'i'),
#  ('kacpi', 'melchior', 'i', 'baltazar'),
#  ('melchior', 'i', 'baltazar', 'na'),
#  ('i', 'baltazar', 'na', 'mieszkanku'),
#  ('baltazar', 'na', 'mieszkanku', 'dzisiaj'),
#  ('na', 'mieszkanku', 'dzisiaj', 'faza'),
#  ('mieszkanku', 'dzisiaj', 'faza', 'dzwonek'),
#  ('dzisiaj', 'faza', 'dzwonek', 'do'),
#  ('faza', 'dzwonek', 'do', 'drzwi'),
#  ('dzwonek', 'do', 'drzwi', 'tyle'),
#  ('do', 'drzwi', 'tyle', 'człowieku'),
#  ('drzwi', 'tyle', 'człowieku', 'stój'),
#  ('tyle', 'człowieku', 'stój', 'czy'),
#  ('człowieku', 'stój', 'czy', 'to'),
#  ('stój', 'czy', 'to', 'są'),
#  ('czy', 'to', 'są', 'psy'),
#  ('to', 'są', 'psy', 'zaraz'),
#  ('są', 'psy', 'zaraz', 'strzeli'),
#  ('psy', 'zaraz', 'strzeli', 'mnie'),
#  ('zaraz', 'strzeli', 'mnie', 'chuj'),
#  ('strzeli', 'mnie', 'chuj', 'zagaście'),
#  ('mnie', 'chuj', 'zagaście', 'szlugi'),
#  ('chuj', 'zagaście', 'szlugi', 'kacpiego'),
#  ('zagaście', 'szlugi', 'kacpiego', 'piję'),
#  ('szlugi', 'kacpiego', 'piję', 'ściszcie'),
#  ('kacpiego', 'piję', 'ściszcie', 'rapsy'),
#  ('piję', 'ściszcie', 'rapsy', 'pierdolę'),
#  ('ściszcie', 'rapsy', 'pierdolę', 'dzwonię'),
#  ('rapsy', 'pierdolę', 'dzwonię', 'popek'),
#  ('pierdolę', 'dzwonię', 'popek', 'bracia'),
#  ('dzwonię', 'popek', 'bracia', 'figo'),
#  ('popek', 'bracia', 'figo', 'fagot'),
#  ('bracia', 'figo', 'fagot', 'plus'),
#  ('figo', 'fagot', 'plus', 'popek'),
#  ('fagot', 'plus', 'popek', 'zryty'),
#  ('plus', 'popek', 'zryty', 'czosnek'),
#  ('popek', 'zryty', 'czosnek', 'królu'),
#  ('zryty', 'czosnek', 'królu', 'albanii'),
#  ('czosnek', 'królu', 'albanii', 'dzisiaj'),
#  ('królu', 'albanii', 'dzisiaj', 'razem'),
#  ('albanii', 'dzisiaj', 'razem', 'na'),
#  ('dzisiaj', 'razem', 'na', 'kwadracie'),
#  ('razem', 'na', 'kwadracie', 'ram'),
#  ('na', 'kwadracie', 'ram', 'pam'),
#  ('kwadracie', 'ram', 'pam', 'pam'),
#  ('ram', 'pam', 'pam', 'pam'),
#  ('pam', 'pam', 'pam', 'dzisiaj'),
#  ('pam', 'pam', 'dzisiaj', 'się'),
#  ('pam', 'dzisiaj', 'się', 'najebie'),
#  ('dzisiaj', 'się', 'najebie', 'razem'),
#  ('się', 'najebie', 'razem', 'z'),
#  ('najebie', 'razem', 'z', 'braćmi'),
#  ('razem', 'z', 'braćmi', 'król'),
#  ('z', 'braćmi', 'król', 'rozjebiemy'),
#  ('braćmi', 'król', 'rozjebiemy', 'całe'),
#  ('król', 'rozjebiemy', 'całe', 'siano'),
#  ('rozjebiemy', 'całe', 'siano', 'idź'),
#  ('całe', 'siano', 'idź', 'pan'),
#  ('siano', 'idź', 'pan', 'w'),
#  ('idź', 'pan', 'w', 'chuj'),
#  ('pan', 'w', 'chuj', 'nic'),
#  ('w', 'chuj', 'nic', 'nie'),
#  ('chuj', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'co'),
#  ('nie', 'pamiętam', 'co', 'się'),
#  ('pamiętam', 'co', 'się', 'działo'),
#  ('co', 'się', 'działo', 'na'),
#  ('się', 'działo', 'na', 'kwadracie'),
#  ('działo', 'na', 'kwadracie', 'nic'),
#  ('na', 'kwadracie', 'nic', 'nie'),
#  ('kwadracie', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'polej'),
#  ('nie', 'pamiętam', 'polej', 'wódki'),
#  ('pamiętam', 'polej', 'wódki', 'bracie'),
#  ('polej', 'wódki', 'bracie', 'najebany'),
#  ('wódki', 'bracie', 'najebany', 'nie'),
#  ('bracie', 'najebany', 'nie', 'pamiętam'),
#  ('najebany', 'nie', 'pamiętam', 'co'),
#  ('nie', 'pamiętam', 'co', 'robiłem'),
#  ('pamiętam', 'co', 'robiłem', 'wczoraj'),
#  ('co', 'robiłem', 'wczoraj', 'czterech'),
#  ('robiłem', 'wczoraj', 'czterech', 'króli'),
#  ('wczoraj', 'czterech', 'króli', 'plus'),
#  ('czterech', 'króli', 'plus', 'pół'),
#  ('króli', 'plus', 'pół', 'litra'),
#  ('plus', 'pół', 'litra', 'plus'),
#  ('pół', 'litra', 'plus', 'wyjebka'),
#  ('litra', 'plus', 'wyjebka', 'na'),
#  ('plus', 'wyjebka', 'na', 'mych'),
#  ('wyjebka', 'na', 'mych', 'schodach'),
#  ('na', 'mych', 'schodach', 'nic'),
#  ('mych', 'schodach', 'nic', 'nie'),
#  ('schodach', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'jezu'),
#  ('nie', 'pamiętam', 'jezu', 'jak'),
#  ('pamiętam', 'jezu', 'jak', 'nakurwia'),
#  ('jezu', 'jak', 'nakurwia', 'mnie'),
#  ('jak', 'nakurwia', 'mnie', 'wątroba'),
#  ('nakurwia', 'mnie', 'wątroba', 'jakiego'),
#  ('mnie', 'wątroba', 'jakiego', 'mam'),
#  ('wątroba', 'jakiego', 'mam', 'kaca'),
#  ('jakiego', 'mam', 'kaca', 'i'),
#  ('mam', 'kaca', 'i', 'gdzie'),
#  ('kaca', 'i', 'gdzie', 'jest'),
#  ('i', 'gdzie', 'jest', 'moja'),
#  ('gdzie', 'jest', 'moja', 'głowa'),
#  ('jest', 'moja', 'głowa', 'to'),
#  ('moja', 'głowa', 'to', 'jest'),
#  ('głowa', 'to', 'jest', 'król'),
#  ('to', 'jest', 'król', 'z'),
#  ('jest', 'król', 'z', 'albanii'),
#  ('król', 'z', 'albanii', 'i'),
#  ('z', 'albanii', 'i', 'bracia'),
#  ('albanii', 'i', 'bracia', 'figo'),
#  ('i', 'bracia', 'figo', 'fagot'),
#  ('bracia', 'figo', 'fagot', 'dawaj'),
#  ('figo', 'fagot', 'dawaj', 'ten'),
#  ('fagot', 'dawaj', 'ten', 'towar'),
#  ('dawaj', 'ten', 'towar', 'usmażę'),
#  ('ten', 'towar', 'usmażę', 'se'),
#  ('towar', 'usmażę', 'se', 'mózg'),
#  ('usmażę', 'se', 'mózg', 'zaraz'),
#  ('se', 'mózg', 'zaraz', 'się'),
#  ('mózg', 'zaraz', 'się', 'dojebię'),
#  ('zaraz', 'się', 'dojebię', 'i'),
#  ('się', 'dojebię', 'i', 'polecę'),
#  ('dojebię', 'i', 'polecę', 'jak'),
#  ('i', 'polecę', 'jak', 'balon'),
#  ('polecę', 'jak', 'balon', 'dokąd'),
#  ('jak', 'balon', 'dokąd', 'mnie'),
#  ('balon', 'dokąd', 'mnie', 'poniesie'),
#  ('dokąd', 'mnie', 'poniesie', 'nie'),
#  ('mnie', 'poniesie', 'nie', 'wie'),
#  ('poniesie', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'bóg'),
#  ('wie', 'nawet', 'bóg', 'dokąd'),
#  ('nawet', 'bóg', 'dokąd', 'nas'),
#  ('bóg', 'dokąd', 'nas', 'poniesie'),
#  ('dokąd', 'nas', 'poniesie', 'nie'),
#  ('nas', 'poniesie', 'nie', 'wie'),
#  ('poniesie', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'tego'),
#  ('wie', 'nawet', 'tego', 'bóg'),
#  ('nawet', 'tego', 'bóg', 'nie'),
#  ('tego', 'bóg', 'nie', 'wie'),
#  ('bóg', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'tego'),
#  ('wie', 'nawet', 'tego', 'bóg'),
#  ('nawet', 'tego', 'bóg', 'nie'),
#  ('tego', 'bóg', 'nie', 'wie'),
#  ('bóg', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'tego'),
#  ('wie', 'nawet', 'tego', 'duch'),
#  ('nawet', 'tego', 'duch', 'nie'),
#  ('tego', 'duch', 'nie', 'wie'),
#  ('duch', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'tego'),
#  ('wie', 'nawet', 'tego', 'król'),
#  ('nawet', 'tego', 'król', 'nie'),
#  ('tego', 'król', 'nie', 'wie'),
#  ('król', 'nie', 'wie', 'nawet'),
#  ('nie', 'wie', 'nawet', 'tego'),
#  ('wie', 'nawet', 'tego', 'chuchla'),
#  ('nawet', 'tego', 'chuchla', 'idź'),
#  ('tego', 'chuchla', 'idź', 'pan'),
#  ('chuchla', 'idź', 'pan', 'w'),
#  ('idź', 'pan', 'w', 'chuj'),
#  ('pan', 'w', 'chuj', 'dzisiaj'),
#  ('w', 'chuj', 'dzisiaj', 'się'),
#  ('chuj', 'dzisiaj', 'się', 'najebie'),
#  ('dzisiaj', 'się', 'najebie', 'razem'),
#  ('się', 'najebie', 'razem', 'z'),
#  ('najebie', 'razem', 'z', 'braćmi'),
#  ('razem', 'z', 'braćmi', 'król'),
#  ('z', 'braćmi', 'król', 'rozjebiemy'),
#  ('braćmi', 'król', 'rozjebiemy', 'całe'),
#  ('król', 'rozjebiemy', 'całe', 'siano'),
#  ('rozjebiemy', 'całe', 'siano', 'idź'),
#  ('całe', 'siano', 'idź', 'pan'),
#  ('siano', 'idź', 'pan', 'w'),
#  ('idź', 'pan', 'w', 'chuj'),
#  ('pan', 'w', 'chuj', 'nic'),
#  ('w', 'chuj', 'nic', 'nie'),
#  ('chuj', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'co'),
#  ('nie', 'pamiętam', 'co', 'się'),
#  ('pamiętam', 'co', 'się', 'działo'),
#  ('co', 'się', 'działo', 'na'),
#  ('się', 'działo', 'na', 'kwadracie'),
#  ('działo', 'na', 'kwadracie', 'nic'),
#  ('na', 'kwadracie', 'nic', 'nie'),
#  ('kwadracie', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'polej'),
#  ('nie', 'pamiętam', 'polej', 'wódki'),
#  ('pamiętam', 'polej', 'wódki', 'bracie'),
#  ('polej', 'wódki', 'bracie', 'figo'),
#  ('wódki', 'bracie', 'figo', 'bania'),
#  ('bracie', 'figo', 'bania', 'goni'),
#  ('figo', 'bania', 'goni', 'banię'),
#  ('bania', 'goni', 'banię', 'niech'),
#  ('goni', 'banię', 'niech', 'ta'),
#  ('banię', 'niech', 'ta', 'bania'),
#  ('niech', 'ta', 'bania', 'nie'),
#  ('ta', 'bania', 'nie', 'ustaje'),
#  ('bania', 'nie', 'ustaje', 'kiedy'),
#  ('nie', 'ustaje', 'kiedy', 'wóda'),
#  ('ustaje', 'kiedy', 'wóda', 'w'),
#  ('kiedy', 'wóda', 'w', 'żyłach'),
#  ('wóda', 'w', 'żyłach', 'nam'),
#  ('w', 'żyłach', 'nam', 'tańcuje'),
#  ('żyłach', 'nam', 'tańcuje', 'kurwa'),
#  ('nam', 'tańcuje', 'kurwa', 'jak'),
#  ('tańcuje', 'kurwa', 'jak', 'się'),
#  ('kurwa', 'jak', 'się', 'super'),
#  ('jak', 'się', 'super', 'czuję'),
#  ('się', 'super', 'czuję', 'trzej'),
#  ('super', 'czuję', 'trzej', 'królowie'),
#  ('czuję', 'trzej', 'królowie', 'na'),
#  ('trzej', 'królowie', 'na', 'kwadracie'),
#  ('królowie', 'na', 'kwadracie', 'rozjebiemy'),
#  ('na', 'kwadracie', 'rozjebiemy', 'wszystko'),
#  ('kwadracie', 'rozjebiemy', 'wszystko', 'w'),
#  ('rozjebiemy', 'wszystko', 'w', 'chacie'),
#  ('wszystko', 'w', 'chacie', 'każde'),
#  ('w', 'chacie', 'każde', 'świństwo'),
#  ('chacie', 'każde', 'świństwo', 'wypijemy'),
#  ('każde', 'świństwo', 'wypijemy', 'dzisiaj'),
#  ('świństwo', 'wypijemy', 'dzisiaj', 'w'),
#  ('wypijemy', 'dzisiaj', 'w', 'kimę'),
#  ('dzisiaj', 'w', 'kimę', 'nie'),
#  ('w', 'kimę', 'nie', 'idziemy'),
#  ('kimę', 'nie', 'idziemy', 'trzy'),
#  ('nie', 'idziemy', 'trzy', 'i'),
#  ('idziemy', 'trzy', 'i', 'wszystkim'),
#  ('trzy', 'i', 'wszystkim', 'wódę'),
#  ('i', 'wszystkim', 'wódę', 'nalewamy'),
#  ('wszystkim', 'wódę', 'nalewamy', 'w'),
#  ('wódę', 'nalewamy', 'w', 'szklany'),
#  ('nalewamy', 'w', 'szklany', 'dwa'),
#  ('w', 'szklany', 'dwa', 'nie'),
#  ('szklany', 'dwa', 'nie', 'marudź'),
#  ('dwa', 'nie', 'marudź', 'dupy'),
#  ('nie', 'marudź', 'dupy', 'w'),
#  ('marudź', 'dupy', 'w', 'górę'),
#  ('dupy', 'w', 'górę', 'i'),
#  ('w', 'górę', 'i', 'śpiewamy'),
#  ('górę', 'i', 'śpiewamy', 'jeden'),
#  ('i', 'śpiewamy', 'jeden', 'chapaj'),
#  ('śpiewamy', 'jeden', 'chapaj', 'wódę'),
#  ('jeden', 'chapaj', 'wódę', 'niech'),
#  ('chapaj', 'wódę', 'niech', 'ryj'),
#  ('wódę', 'niech', 'ryj', 'pali'),
#  ('niech', 'ryj', 'pali', 'i'),
#  ('ryj', 'pali', 'i', 'w'),
#  ('pali', 'i', 'w', 'górę'),
#  ('i', 'w', 'górę', 'i'),
#  ('w', 'górę', 'i', 'w'),
#  ('górę', 'i', 'w', 'górę'),
#  ('i', 'w', 'górę', 'i'),
#  ('w', 'górę', 'i', 'w'),
#  ('górę', 'i', 'w', 'górę'),
#  ('i', 'w', 'górę', 'trzy'),
#  ('w', 'górę', 'trzy', 'dwa'),
#  ('górę', 'trzy', 'dwa', 'jeden'),
#  ('trzy', 'dwa', 'jeden', 'trzy'),
#  ('dwa', 'jeden', 'trzy', 'dwa'),
#  ('jeden', 'trzy', 'dwa', 'jeden'),
#  ('trzy', 'dwa', 'jeden', 'lufa'),
#  ('dwa', 'jeden', 'lufa', 'dzisiaj'),
#  ('jeden', 'lufa', 'dzisiaj', 'się'),
#  ('lufa', 'dzisiaj', 'się', 'najebie'),
#  ('dzisiaj', 'się', 'najebie', 'razem'),
#  ('się', 'najebie', 'razem', 'z'),
#  ('najebie', 'razem', 'z', 'braćmi'),
#  ('razem', 'z', 'braćmi', 'król'),
#  ('z', 'braćmi', 'król', 'rozjebiemy'),
#  ('braćmi', 'król', 'rozjebiemy', 'całe'),
#  ('król', 'rozjebiemy', 'całe', 'siano'),
#  ('rozjebiemy', 'całe', 'siano', 'idź'),
#  ('całe', 'siano', 'idź', 'pan'),
#  ('siano', 'idź', 'pan', 'w'),
#  ('idź', 'pan', 'w', 'chuj'),
#  ('pan', 'w', 'chuj', 'nic'),
#  ('w', 'chuj', 'nic', 'nie'),
#  ('chuj', 'nic', 'nie', 'pamiętam'),
#  ('nic', 'nie', 'pamiętam', 'co'),
#  ('nie', 'pamiętam', 'co', 'się'),
#  ('pamiętam', 'co', 'się', 'działo'),
#  ('co', 'się', 'działo', 'na'),
#  ('się', 'działo', 'na', 'kwadracie')]

# %%
df['trigram']= df.text.apply(lambda x : list(ngrams(word_tokenize(x),3)))

# %%
df['fourgram']= df.text.apply(lambda x : list(ngrams(word_tokenize(x),4)))

# %%
words = df['words']

# %%
words=words.tolist()

# %%
words=sum(words,[])

# %%
from collections import Counter
from nltk.util import ngrams 

text = words
n_gram = 4
x=Counter(ngrams(text, n_gram))

# %%
xx =dict(x)
sorted(xx.items(), key=lambda x: x[1], reverse=True)
pd.DataFrame(sorted(xx.items(), key=lambda x: x[1], reverse=True), columns=["slowa", "liczba"]).head(50)
# Out:
#                                           slowa  liczba
# 0                              (ra, ra, ra, ra)      30
# 1                              (la, la, la, la)      21
# 2      (ciuralla, ciuralla, ciuralla, ciuralla)      16
# 3                      (bal, bal, disco, rżnie)      12
# 4                     (bal, disco, rżnie, full)      12
# 5              (miłość, miłość, miłość, miłość)      12
# 6               (świruj, świnio, tańcz, świruj)      12
# 7                    (disco, polo, disco, polo)      11
# 8                     (disco, rżnie, full, bal)       9
# 9                       (rżnie, full, bal, bal)       9
# 10                      (full, bal, bal, disco)       9
# 11                 (chłop, chłop, chłop, chłop)       9
# 12                  (mętne, oczy, mętny, wzrok)       9
# 13                  (oczy, mętny, wzrok, mętne)       9
# 14                  (mętny, wzrok, mętne, oczy)       9
# 15               (tańcz, świruj, świnio, tańcz)       9
# 16  (zalegizybać, marichuanen, żadnym, wypadku)       9
# 17              (świnio, tańcz, świruj, świnio)       8
# 18            (podobno, podobno, robiła, łóżku)       8
# 19                             (pa, pa, pa, pa)       6
# 20            (ciuralla, ciuralla, weź, mojego)       6
# 21            (ciuralla, weź, mojego, siuralla)       6
# 22                  (wzrok, mętne, oczy, mętny)       6
# 23                         (ooo, ooo, ooo, ooo)       6
# 24               (jaka, miłość, miłość, miłość)       6
# 25     (jabadaba, jabadaba, jabadaba, jabadaba)       6
# 26                (tańcz, tańcz, świnko, tańcz)       6
# 27                    (gra, disco, polo, disco)       5
# 28                    (polo, disco, polo, inni)       5
# 29                (disco, polo, inni, pierdolą)       5
# 30                (polo, inni, pierdolą, metal)       5
# 31                 (inni, pierdolą, metal, rap)       5
# 32                  (pierdolą, metal, rap, mym)       5
# 33                 (metal, rap, mym, serduszku)       5
# 34                   (rap, mym, serduszku, gra)       5
# 35                (polo, disco, polo, lalalala)       5
# 36          (muzyczne, trendy, pogoda, zmienne)       5
# 37             (trendy, pogoda, zmienne, disco)       5
# 38              (pogoda, zmienne, disco, dalej)       5
# 39                (zmienne, disco, dalej, trwa)       5
# 40                  (disco, dalej, trwa, metal)       5
# 41              (dalej, trwa, metal, punkowiec)       5
# 42             (skórą, ruszyła, konia, zwaliła)       5
# 43                         (myk, myk, myk, myk)       5
# 44              (bujaj, łbem, przodu, zginiesz)       5
# 45              (łbem, przodu, zginiesz, głodu)       5
# 46              (tanie, brzydkie, figo, pożycz)       5
# 47                 (brzydkie, figo, pożycz, 50)       5
# 48                    (figo, pożycz, 50, tanie)       5
# 49                (pożycz, 50, tanie, brzydkie)       5

# %%
from textblob import TextBlob

# %%
blob = TextBlob("jest fajnie")

# %%
blob=blob.translate(to="en")

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.35, subjectivity=0.65)

# %%
df["polarity_pl"] = df.text.apply(lambda x: TextBlob(x).polarity)

# %%
df["polarity_en"] = df.text.apply(lambda x: TextBlob(x).translate(to="en").polarity)

# %%
df[['names', 'polarity_pl', 'polarity_en']].iloc[50:]
# Out:
#                                names  polarity_pl  polarity_en
# 50  Pioseneczka o woreczku mosznowym     0.333333     0.160000
# 51            Piosenka dla Kapuczino     0.000000    -0.300000
# 52                    Pisarz miłości     0.000000     0.039158
# 53     Podobno nigdy tego nie robiła     0.000000     0.087415
# 54                  Polej Gruby Wódy     0.000000     0.014286
# 55                            Polska     0.250000     0.078986
# 56                        Pościelówa     0.000000     0.008891
# 57                 Punkt bez powrotu     0.000000     0.002564
# 58                     Świnki i Damy     0.000000     0.177778
# 59                  Tańczyła z brate     0.000000     0.120000
# 60                            Teresa     0.000000    -0.168998
# 61                        Ugi Boogie     0.000000    -0.054545
# 62                            Wesele     0.000000    -0.109776
# 63                   Wędkarz miłości     0.000000     0.100106
# 64                    Wojownicy Wódy     0.000000     0.089062
# 65                  Wóda zryje banię     0.000000    -0.056800
# 66          Z wędziskiem za pan brat     0.000000     0.000000
# 67             Zalegizybać Marihuaen     0.000000     0.242982
# 68        Zobacz dziwko co narobiłaś     0.000000    -0.018448

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 5).generate(" ".join(words))

import matplotlib.pyplot as plt

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
words
# Out:
# ['czterdzieści',
#  'cztery',
#  'puszki',
#  'torba',
#  'zmieści',
#  'czterech',
#  'króli',
#  'doniosę',
#  'jebnę',
#  'drodze',
#  'gul',
#  'gul',
#  'gul',
#  'ahhh',
#  'stajence',
#  'siatce',
#  'kacpi',
#  'melchior',
#  'baltazar',
#  'mieszkanku',
#  'faza',
#  'dzwonek',
#  'drzwi',
#  'tyle',
#  'człowieku',
#  'stój',
#  'psy',
#  'zaraz',
#  'strzeli',
#  'chuj',
#  'zagaście',
#  'szlugi',
#  'kacpiego',
#  'piję',
#  'ściszcie',
#  'rapsy',
#  'pierdolę',
#  'dzwonię',
#  'popek',
#  'bracia',
#  'figo',
#  'fagot',
#  'plus',
#  'popek',
#  'zryty',
#  'czosnek',
#  'królu',
#  'albanii',
#  'razem',
#  'kwadracie',
#  'ram',
#  'pam',
#  'pam',
#  'pam',
#  'najebie',
#  'razem',
#  'braćmi',
#  'król',
#  'rozjebiemy',
#  'całe',
#  'siano',
#  'idź',
#  'chuj',
#  'pamiętam',
#  'działo',
#  'kwadracie',
#  'pamiętam',
#  'polej',
#  'wódki',
#  'bracie',
#  'najebany',
#  'pamiętam',
#  'robiłem',
#  'wczoraj',
#  'czterech',
#  'króli',
#  'plus',
#  'pół',
#  'litra',
#  'plus',
#  'wyjebka',
#  'mych',
#  'schodach',
#  'pamiętam',
#  'jezu',
#  'nakurwia',
#  'wątroba',
#  'jakiego',
#  'kaca',
#  'głowa',
#  'król',
#  'albanii',
#  'bracia',
#  'figo',
#  'fagot',
#  'dawaj',
#  'towar',
#  'usmażę',
#  'se',
#  'mózg',
#  'zaraz',
#  'dojebię',
#  'polecę',
#  'balon',
#  'poniesie',
#  'bóg',
#  'poniesie',
#  'bóg',
#  'bóg',
#  'duch',
#  'król',
#  'chuchla',
#  'idź',
#  'chuj',
#  'najebie',
#  'razem',
#  'braćmi',
#  'król',
#  'rozjebiemy',
#  'całe',
#  'siano',
#  'idź',
#  'chuj',
#  'pamiętam',
#  'działo',
#  'kwadracie',
#  'pamiętam',
#  'polej',
#  'wódki',
#  'bracie',
#  'figo',
#  'bania',
#  'goni',
#  'banię',
#  'bania',
#  'ustaje',
#  'wóda',
#  'żyłach',
#  'tańcuje',
#  'kurwa',
#  'super',
#  'czuję',
#  'trzej',
#  'królowie',
#  'kwadracie',
#  'rozjebiemy',
#  'chacie',
#  'każde',
#  'świństwo',
#  'wypijemy',
#  'kimę',
#  'idziemy',
#  'trzy',
#  'wódę',
#  'nalewamy',
#  'szklany',
#  'marudź',
#  'dupy',
#  'górę',
#  'śpiewamy',
#  'chapaj',
#  'wódę',
#  'ryj',
#  'pali',
#  'górę',
#  'górę',
#  'górę',
#  'trzy',
#  'trzy',
#  'lufa',
#  'najebie',
#  'razem',
#  'braćmi',
#  'król',
#  'rozjebiemy',
#  'całe',
#  'siano',
#  'idź',
#  'chuj',
#  'pamiętam',
#  'działo',
#  'kwadracie',
#  'posłuchaj',
#  'seba',
#  'odstaw',
#  'chwilę',
#  'piwo',
#  'popatrz',
#  'górę',
#  'nieba',
#  'małe',
#  'odziwo',
#  'wysoko',
#  'głową',
#  'hoho',
#  'skowronek',
#  'kwili',
#  'disco',
#  'polo',
#  'non',
#  'stop',
#  'leci',
#  'mono',
#  'tonsili',
#  'ptak',
#  'samolot',
#  'disco',
#  'pola',
#  'łomot',
#  'burza',
#  'grad',
#  'disco',
#  'pola',
#  'czad',
#  'lubi',
#  'disco',
#  'polo',
#  'bydle',
#  'cham',
#  'lubi',
#  'disco',
#  'polo',
#  'zazna',
#  'nieba',
#  'bram',
#  '2',
#  'żem',
#  'wracał',
#  'niemczech',
#  'chemią',
#  'szwagier',
#  'kółkiem',
#  'zmógł',
#  'sen',
#  'sen',
#  'zrobiło',
#  'lekko',
#  'mnei',
#  'matka',
#  'wzięła',
#  'swe',
#  'spracowane',
#  'ramiona',
#  'przebudziłem',
#  'dokoła',
#  'ojczyzna',
#  'rodziłem',
#  'zdechnę',
#  'czapla',
#  'gołąb',
#  'disco',
#  'pola',
#  'łomot',
#  'tarpan',
#  'fiat',
#  'disco',
#  'pola',
#  'czad',
#  'lubi',
#  'disco',
#  'polo',
#  'kurwa',
#  'chuj',
#  'lubi',
#  'disco',
#  'polo',
#  'piekle',
#  'smaży',
#  '3',
#  'sobotę',
#  'prądzie',
#  'dłubałem',
#  'żyrandol',
#  'buntował',
#  'chyba',
#  'nacisnąłem',
#  'świat',
#  'nagle',
#  'zawirował',
#  'zbudziłem',
#  'chmurce',
#  'niebie',
#  'anioł',
#  'podleciał',
#  'wcisnął',
#  'plajplay',
#  'rzekł',
#  'disco',
#  'polo',
#  'rytmie',
#  'hula',
#  'raj',
#  'agregat',
#  'uprawowy',
#  'dicopolo',
#  'rytm',
#  'miarowy',
#  'ładowacz',
#  'zaczepiany',
#  'discopolo',
#  'bit',
#  'znany',
#  'lubi',
#  'discopolo',
#  'kocha',
#  'matki',
#  'swej',
#  'spotkałem',
#  'lquano',
#  'disco',
#  'dawidach',
#  'chwilę',
#  'spoglądałem',
#  'oceniałem',
#  'odstawiłem',
#  'drina',
#  'dobra',
#  'idę',
#  'podchodzę',
#  'patrzy',
#  'spode',
#  'łba',
#  'mówię',
#  'heloł',
#  'bejbe',
#  'łot',
#  'jor',
#  'nejm',
#  'ajem',
#  'usa',
#  'łi',
#  'low',
#  'mówię',
#  'potem',
#  'gapi',
#  'kurwa',
#  'zrobiłem',
#  'źle',
#  'gęby',
#  'wali',
#  'gumę',
#  'żuję',
#  'nagle',
#  'takim',
#  'tekstem',
#  'wyskakuje',
#  'wysilaj',
#  'grubasku',
#  'rozpoznałam',
#  'pomagasz',
#  'autoserwisie',
#  'smarze',
#  'chodzisz',
#  'całe',
#  'dnie',
#  'nakręca',
#  'bajera',
#  'świnie',
#  'testosteron',
#  'level',
#  'max',
#  'żyłach',
#  'alko',
#  'płynie',
#  'szanse',
#  'nosisz',
#  'zdejmij',
#  'bryle',
#  'udaje',
#  'da',
#  'świnia',
#  'ryle',
#  'następnej',
#  'udaj',
#  'spotkałem',
#  'masarni',
#  'zwanym',
#  'sklepie',
#  'firmowy',
#  'stała',
#  'taką',
#  'grubą',
#  'babą',
#  'podobną',
#  'trochę',
#  'krowy',
#  'śliczna',
#  'dziewczyna',
#  'stara',
#  'takim',
#  'ryjem',
#  'matka',
#  'roztyje',
#  'mówię',
#  'ryzyk',
#  'fizyk',
#  'idę',
#  'poprawiłem',
#  'włosy',
#  'łbie',
#  'podchodzę',
#  'zagaduję',
#  'stara',
#  'ryjem',
#  'kolejka',
#  'żebym',
#  'wpychał',
#  'przyjebała',
#  'torebką',
#  'chwile',
#  'czułem',
#  'jakbym',
#  'zdychał',
#  'bydlak',
#  'świnia',
#  'kolejkę',
#  'krzywego',
#  'ryja',
#  'łeb',
#  'torebki',
#  'wypad',
#  'stary',
#  'kurwa',
#  'smaru',
#  'ślady',
#  'nakręca',
#  'bajera',
#  'świnie',
#  'testosteron',
#  'level',
#  'max',
#  'żyłach',
#  'alko',
#  'płynie',
#  'szanse',
#  'nosisz',
#  'zdejmij',
#  'bryle',
#  'udaje',
#  'da',
#  'świnia',
#  'ryle',
#  'następnej',
#  'udaj',
#  'spotkałem',
#  'plaży',
#  'mielnie',
#  'zejściu',
#  'foce',
#  'bosaka',
#  'bikini',
#  'pali',
#  'szluga',
#  'pocę',
#  'ręką',
#  'przecieram',
#  'czoło',
#  'badam',
#  'skrzydła',
#  'podbijam',
#  'pali',
#  'znaczy',
#  'strasznie',
#  'łatwa',
#  'świnia',
#  'matka',
#  'saper',
#  'masz',
#  'bombową',
#  'figurę',
#  'chyba',
#  'działa',
#  'zza',
#  'oksów',
#  'mocno',
#  'wzrokiem',
#  'taksuje',
#  'gdybyś',
#  'piaskiem',
#  'bejbe',
#  'babki',
#  'robił',
#  'kopa',
#  'dała',
#  'jaja',
#  'zesrałem',
#  'siebie',
#  'weź',
#  'wkurwiaj',
#  'chłopaku',
#  'rozpoznałam',
#  'jesteś',
#  'mielna',
#  'pablo',
#  'zupę',
#  'wcinaj',
#  'pierdol',
#  'nakręca',
#  'bajera',
#  'świnie',
#  'testosteron',
#  'level',
#  'max',
#  'żyłach',
#  'alko',
#  'płynie',
#  'szanse',
#  'nosisz',
#  'zdejmij',
#  'bryle',
#  'udaje',
#  'da',
#  'świnia',
#  'ryle',
#  'metal',
#  'długie',
#  'włosy',
#  'disco',
#  'gra',
#  'hiphop',
#  'krok',
#  'kolanach',
#  'disco',
#  'gra',
#  'bawią',
#  'bawią',
#  'bawią',
#  'tańczą',
#  'śmieją',
#  'disco',
#  'gra',
#  'wkoło',
#  'wesoło',
#  'wesoło',
#  'disco',
#  'gra',
#  'metal',
#  'ambitny',
#  'hip',
#  'hop',
#  'prawdziwy',
#  'disco',
#  'gra',
#  'muzyka',
#  'lepsza',
#  'disco',
#  'dalej',
#  'gra',
#  'disco',
#  'polo',
#  'disco',
#  'polo',
#  'inni',
#  'pierdolą',
#  'metal',
#  'rap',
#  'mym',
#  'serduszku',
#  'gra',
#  'polo',
#  'disco',
#  'polo',
#  'lalalala',
#  'lalala',
#  'loolo',
#  'country',
#  'jazz',
#  'pocałujcie',
#  'dupy',
#  'kamil',
#  'grosicki',
#  'piłkę',
#  'gra',
#  'hucie',
#  'hutnik',
#  'dmucha',
#  'szkła',
#  'disco',
#  'gra',
#  'żołnierz',
#  'froncie',
#  'karabin',
#  'rytm',
#  'disco',
#  'polo',
#  'tratatata',
#  'rolnik',
#  'gnoju',
#  'złotówiarz',
#  'postoju',
#  'dziewczyny',
#  'burdelu',
#  'każdym',
#  'weselu',
#  'żadnej',
#  'imprezie',
#  'nikt',
#  'obrazi',
#  'disco',
#  'polo',
#  'zagra',
#  'disco',
#  'polo',
#  'disco',
#  'polo',
#  'inni',
#  'pierdolą',
#  'metal',
#  'rap',
#  'mym',
#  'serduszku',
#  'gra',
#  'polo',
#  'disco',
#  'polo',
#  'lalalala',
#  'lalala',
#  'loolo',
#  'country',
#  'jazz',
#  'pocałujcie',
#  'dupy',
#  'muzyczne',
#  'trendy',
#  'pogoda',
#  'zmienne',
#  'disco',
#  'dalej',
#  'trwa',
#  'metal',
#  'punkowiec',
#  'emo',
#  'ziomal',
#  'disco',
#  'zna',
#  'la',
#  'la',
#  'la',
#  'muzyczne',
#  'trendy',
#  'pogoda',
#  'zmienne',
#  'disco',
#  'dalej',
#  'trwa',
#  'metal',
#  'punkowiec',
#  'emo',
#  'ziomal',
#  'disco',
#  'zna',
#  'dziękujemy',
#  'serdecznie',
#  'zapraszamy',
#  'bufetu',
#  'krótka',
#  'przerwa',
#  'gramy',
#  'dalej',
#  'północy',
#  'dancing',
#  'augustów',
#  'albatros',
#  'dziękujemy',
#  'lalalala',
#  'disco',
#  'pololo',
#  'disco',
#  'polololo',
#  'lalala',
#  'la',
#  'lololoło',
#  'disco',
#  'polo',
#  'disco',
#  'polo',
#  'disco',
#  'polo',
#  'disco',
#  'polo',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'parkiecie',
#  'świński',
#  'tłum',
#  'świnki',
#  'cieszą',
#  'disco',
#  'rżnie',
#  'świniobij',
#  'ruszam',
#  'dance',
#  'trzody',
#  'chlewnej',
#  'zebranej',
#  'remizie',
#  'wybrałem',
#  'jedną',
#  'cizie',
#  'skoro',
#  'śpiewam',
#  'domyślasz',
#  'tą',
#  'cizią',
#  'jesteś',
#  'bądź',
#  'nieśmiała',
#  'daj',
#  'dupy',
#  'kochana',
#  'raczej',
#  'będziesz',
#  'żałowała',
#  'widzisz',
#  'wąs',
#  'czytaj',
#  'best',
#  'mężczyzną',
#  'twoich',
#  'oczach',
#  'widzę',
#  'seks',
#  'laleczko',
#  'parkiecie',
#  'zróbmy',
#  'toalecie',
#  'kabina',
#  'numer',
#  'sześć',
#  'zamek',
#  'słońce',
#  'dochodzi',
#  'dojdę',
#  'mów',
#  'znałaś',
#  'wiedziałaś',
#  'zbyt',
#  'chętnie',
#  'kabiny',
#  'wpakowałaś',
#  'mów',
#  'lubisz',
#  'uwierzę',
#  '50',
#  'procent',
#  'świnek',
#  'dupę',
#  'bierze',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'parking',
#  'star',
#  'kabinie',
#  'discopolo',
#  'radiu',
#  'łka',
#  'piosence',
#  'jesteś',
#  'szalona',
#  'realu',
#  'kłoda',
#  'mówiłaś',
#  'puściłaś',
#  'drinki',
#  'waliłaś',
#  'obiecywałaś',
#  'dupy',
#  'dałaś',
#  'bogolem',
#  'poldkiem',
#  'odjechałaś',
#  'biednego',
#  'olałaśchoć',
#  'obiecałaś',
#  'poloneza',
#  'atu',
#  'plus',
#  'poleciałaś',
#  'mów',
#  'forsy',
#  'lubisz',
#  'śmiechem',
#  'parsknę',
#  '100',
#  'procent',
#  'świnek',
#  'leci',
#  'kasę',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'bal',
#  'bal',
#  'disco',
#  'rżnie',
#  'full',
#  'matka',
#  'mówiła',
#  'wracał',
#  'szkoły',
#  'zerknij',
#  'synu',
#  'zeszyty',
#  'wolał',
#  'iść',
#  'bojo',
#  'przyszedł',
#  'maj',
#  'zakwitły',
#  'kasztany',
#  'staś',
#  'strzepnął',
#  'końcówkę',
#  'piwa',
#  'maturę',
#  'poszedł',
#  'jednostka',
#  'przasnyszu',
#  'stu',
#  'poborowych',
#  'staś',
#  'kartkę',
#  'przysięgą',
#  'rozwija',
#  'dostrzegł',
#  'chorąży',
#  'dostrzegł',
#  'młody',
#  'kot',
#  'noc',
#  'capstrzyku',
#  'trzepanie',
#  'wicków',
#  'zaliczał',
#  'drużynce',
#  'rejon',
#  'pucował',
#  'żołnierz',
#  'wojska',
#  'polskiego',
#  'przysięgam',
#  'służyć',
#  'wiernie',
#  'rzeczypospolitej',
#  'polskiej',
#  'bronić',
#  'niepodległości',
#  'granic',
#  'stać',
#  'straży',
#  'konstytucji',
#  'strzec',
#  'honoru',
#  'żołnierza',
#  'polskiego',
#  'sztandaru',
#  'wojskowego',
#  'bronić',
#  'sprawę',
#  'mej',
#  'ojczyzny',
#  'potrzebie',
#  'krwi',
#  'własnej',
#  'życia',
#  'szczędzić',
#  '2',
#  'półtorej',
#  'minęło',
#  'bicza',
#  'stach',
#  'centymetr',
#  'krawiecki',
#  'kupił',
#  'bp',
#  'wybłagał',
#  'pejotkę',
#  'domu',
#  'zajechał',
#  'goździków',
#  'nazrywał',
#  'mama',
#  'małgosia',
#  'smutna',
#  'wskazała',
#  'tabor',
#  'pił',
#  'cztery',
#  'noce',
#  'bójki',
#  'wdawał',
#  'barem',
#  'stanęło',
#  'wsw',
#  'stach',
#  'anclu',
#  'tydzień',
#  'przepłakał',
#  'falomierz',
#  'obcięty',
#  'połowy',
#  'stach',
#  'młode',
#  'wojsko',
#  'dociera',
#  'dola',
#  'żołnierza',
#  'prostu',
#  'żołnierz',
#  'wojska',
#  'polskiego',
#  'przysięgam',
#  'służyć',
#  'wiernie',
#  'rzeczypospolitej',
#  'polskiej',
#  'bronić',
#  'niepodległości',
#  'granic',
#  'stać',
#  'straży',
#  'konstytucji',
#  'strzec',
#  'honoru',
#  'żołnierza',
#  'polskiego',
#  'sztandaru',
#  'wojskowego',
#  'bronić',
#  'sprawę',
#  'mej',
#  'ojczyzny',
#  'potrzebie',
#  'bamboleo',
#  'zepsute',
#  'mondeo',
#  'ecie',
#  'pecie',
#  'stoi',
#  'lawecie',
#  'ore',
#  'eru',
#  'sześć',
#  'koła',
#  'papieru',
#  'całe',
#  'psu',
#  'dupę',
#  'mogłem',
#  'brać',
#  'mégane',
#  'coupé',
#  ...]
